# %% [markdown]
# # Indicators of Compromise API
# This notebook demonstrates how to use the Indicators of Compromise API (TCA-0330).
#
# **NOTE:** If pasted into a Python file in the displayed order, all code cells can also work as a Python script.

# %% [markdown]
# ### Covered API classes
# This notebook covers examples for the following API class:
# - **IocDataRetrieval** (*TCA-0330*)
#
# ### Credentials
# Credentials are loaded from a local file instead of being written here in plain text.
# To learn how to creat the credentials file, see the **Storing and using the credentials** section in the [README file](./README.md)
#
# 1. Importing the required class
# First, we will import the required API class from the ticloud module.

# %%
from ReversingLabs.SDK.ticloud import IocDataRetrieval
from datetime import datetime, timedelta

# %% [markdown]
# ### 2. Loading the credentials
# Next, we will load our Spectra Intelligence credentials from the local `ticloud_credentials.json` file.
# **NOTE: Instead of doing this step, you can paste your credentials while creating the Python object in the following step.**

# %%
import json


CREDENTIALS = json.load(open("ticloud_credentials.json"))
USERNAME = CREDENTIALS.get("username")
PASSWORD = CREDENTIALS.get("password")
USER_AGENT = json.load(open('../user_agent.json'))["user_agent"]

# %% [markdown]
# ### 3. Creating the IocDataRetrieval object
# After we create an object from the IocDataRetrieval class, we will be able to use its methods.

# %%
ioc = IocDataRetrieval(
    host="https://data.reversinglabs.com",
    username=USERNAME,
    password=PASSWORD,
    user_agent=USER_AGENT
)

# %% [markdown]
# ### 4. Fetching the Indicators of Compromise with defined time
# We will now fetch IoCs by specifying several parameters:
# - only sample type IoCs
# - only malicious IoCs
# - time will be defined as a Unix timestamp
# - time period will be last 12 hours

# %%
twelve_hours = datetime.now() - timedelta(hours=12)
timestamp = str(int(twelve_hours.timestamp()))

response = ioc.get_iocs_timerange(
    ioc_type="sample",
    time_format="timestamp",
    time_value=timestamp,
    classification="malicious"
)

print(response.text)

# %% [markdown]
# ### 5. Fetching the latest Indicators of Compromise
# We will now fetch only the latest IoCs.

# %%
response = ioc.get_latest_iocs(
    ioc_type="sample",
    classification="malicious"
)

print(response.text)

# %% [markdown]
# ### 6. Fetching the number of available Indicators of Compromise
# Now we will only fetch the number of available IoCs withing the defined time period.

# %%
response = ioc.get_ioc_summary(
    ioc_type="sample",
    time_format="timestamp",
    time_value=timestamp,
    classification="malicious"
)

print(response.text)
